# %%
import pandas as pd
import pandas as pd
import numpy as np
import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import plot_confusion_matrix
from sklearn.dummy import DummyClassifier
from sklearn.linear_model import LogisticRegression
import pandas as pd
import numpy as np
import datetime
import warnings
with warnings.catch_warnings():
    warnings.filterwarnings("ignore",category=DeprecationWarning)
    import sklearn

# required machine learning packages
from sklearn import model_selection
from sklearn.feature_selection import RFE
from sklearn.metrics import brier_score_loss, roc_auc_score
from sklearn.naive_bayes import GaussianNB
from sklearn.neighbors import KNeighborsClassifier
from sklearn.discriminant_analysis import LinearDiscriminantAnalysis as LDA
from sklearn.linear_model import LogisticRegression
from sklearn.calibration import CalibratedClassifierCV as CCV

from sklearn.neural_network import MLPClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier, AdaBoostClassifier, VotingClassifier
from sklearn.model_selection import cross_val_score
from sklearn.metrics import accuracy_score, recall_score, precision_score, f1_score
import matplotlib.pyplot as plt 
# %matplotlib inline

# %%
stadiums = pd.read_csv('data/nfl_stadiums.csv')

# %%
spread = pd.read_csv('data/spreadspoke_scores.csv')

# %%
teams = pd.read_csv('data/nfl_teams.csv')

# %% [markdown]
# # A little about betting

# %% [markdown]
# ## What is a point spread? Why does it usually have a .5 at the end?
#
# ### The point spread is the expected final score difference between two teams. It is represented as both a negative and positive number; if the spread is 3 points, you'll see that as both -3 and +3. The team that is the favorite to win gets the minus-number (-3); the underdog gets the plus-number (+3).
#
# ### But the actual number itself, ignoring the plus-minus sign, will always be the same for both teams, because, again, that's the expected margin of victory.
#
# ### If Team A is a 3-point favorite over Team B, Team A has to win by more than 3 points to win the bet, or "cover." Team B can win the game outright or lose by one or two points (but no more than that) and they "cover."
#
# https://www.foxsports.com/stories/nfl/point-spread-over-under

# %% [markdown]
# # Why is this important?
#
# ### An estimated 45.2 million Americans plan to wager on the NFL season in some form, up 36% from last year, according to research from the American Gaming Association. At least
#
# ### 12 billion will be bet on the NFL this season, according to sports betting market tracker PlayUSA.
#
# https://www.cnbc.com/2021/09/09/more-americans-will-wager-on-the-nfl-as-the-league-embraces-betting.html
#
# # The Quesion Being Posed Here
#
# ### What can you expect your monthly income to be if you bet the spread of games each week

# %% [markdown]
# ## Stadiums
#
# ### I need absolutely nothing from this particular CSV there is also a ton of nan factors and outdated stadiums I won't be utilizing this in my model but it takes 12.5 KB so I will be hashtagging out of this.

# %%
#stadiums.info()

# %% [markdown]
# ## Spread
#
# ### I will  be dropping schedule date as I don't think the day has a correlation on spread
# ### I will be dropping schedule season prior to 2012 as I want to do a 10 year tenure
# ### Schedule week does not have a direct correlation to the over or under of the spread
# ### I don't want schedule_playoff to play a part in over under spread either
#
# ### Team_Home will be kept
# ### Score_Home will be kept
# ### Score away will be kept
# ### Team_Away will be kept
# ### Team Favorite Id will be kept
# ### Spread_favorite Target Variable
# ### Over_under_line dropped for now
# ### Stadium Dropped
# ### Stadium neutal dropped
# ### All Weather ccolumns will be dropped
# ### schedule_dropped below 2013. completed.

# %%
spread
spread.drop(index = spread[spread['schedule_season'] <= 2012].index, inplace = True)
spread = spread.replace(r'^\s*$', np.nan, regex=True)

# removing rows from specific columns that have null values, resetting index and changing data types
spread.isnull().sum()
# Out:
# schedule_date             0
# schedule_season           0
# schedule_week             0
# schedule_playoff          0
# team_home                 0
# score_home                1
# score_away                1
# team_away                 0
# team_favorite_id          0
# spread_favorite           0
# over_under_line           0
# stadium                   0
# stadium_neutral           0
# weather_temperature     540
# weather_wind_mph        542
# weather_humidity       2184
# weather_detail         1674
# dtype: int64

# %%
spread['team_home'].str.strip()
# Out:
# 10809          Denver Broncos
# 10810           Buffalo Bills
# 10811       Carolina Panthers
# 10812           Chicago Bears
# 10813        Cleveland Browns
#                  ...
# 13227      Kansas City Chiefs
# 13228    Tampa Bay Buccaneers
# 13229      Kansas City Chiefs
# 13230        Los Angeles Rams
# 13231        Los Angeles Rams
# Name: team_home, Length: 2423, dtype: object

# %%
spread
# Out:
#       schedule_date  schedule_season schedule_week  schedule_playoff  \
# 10809      9/5/2013             2013             1             False
# 10810      9/8/2013             2013             1             False
# 10811      9/8/2013             2013             1             False
# 10812      9/8/2013             2013             1             False
# 10813      9/8/2013             2013             1             False
# ...             ...              ...           ...               ...
# 13227     1/23/2022             2021      Division              True
# 13228     1/23/2022             2021      Division              True
# 13229     1/30/2022             2021    Conference              True
# 13230     1/30/2022             2021    Conference              True
# 13231     2/13/2022             2021     Superbowl              True
#
#                   team_home  score_home  score_away             team_away  \
# 10809        Denver Broncos        49.0        27.0      Baltimore Ravens
# 10810         Buffalo Bills        21.0        23.0  New England Patriots
# 10811     Carolina Panthers         7.0        12.0      Seattle Seahawks
# 10812         Chicago Bears        24.0        21.0    Cincinnati Bengals
# 10813      Cleveland Browns        10.0        23.0        Miami Dolphins
# ...                     ...         ...         ...                   ...
# 13227    Kansas City Chiefs        42.0        36.0         Buffalo Bills
# 13228  Tampa Bay Buccaneers        27.0        30.0      Los Angeles Rams
# 13229    Kansas City Chiefs        24.0        27.0    Cincinnati Bengals
# 13230      Los Angeles Rams        20.0        17.0   San Francisco 49ers
# 13231      Los Angeles Rams         NaN         NaN    Cincinnati Bengals
#
#       team_favorite_id  spread_favorite over_under_line  \
# 10809              DEN             -7.5            49.5
# 10810               NE            -10.5            51.5
# 10811              SEA             -3.5              45
# 10812              CHI             -3.0              42
# 10813              CLE             -2.5            40.5
# ...                ...              ...             ...
# 13227               KC             -2.5            54.0
# 13228               TB             -3.0            48.0
# 13229               KC             -7.0            54.5
# 13230              LAR             -3.5            46.0
# 13231              LAR             -4.0            48.5
#
#                                    stadium  stadium_neutral  \
# 10809  Sports Authority Field at Mile High            False
# 10810                 Ralph Wilson Stadium            False
# 10811              Bank of America Stadium            False
# 10812                        Soldier Field            False
# 10813                  FirstEnergy Stadium            False
# ...                                    ...              ...
# 13227                    Arrowhead Stadium            False
# 13228                Raymond James Stadium            False
# 13229                    Arrowhead Stadium            False
# 13230                         SoFi Stadium            False
# 13231                         SoFi Stadium             True
#
#        weather_temperature  weather_wind_mph  weather_humidity weather_detail
# 10809                 83.0               7.0              30.0            NaN
# 10810                 65.0               6.0              55.0            NaN
# 10811                 87.0               7.0              48.0            NaN
# 10812                 77.0              13.0              79.0            NaN
# 10813                 72.0              16.0              80.0            NaN
# ...                    ...               ...               ...            ...
# 13227                 35.0               6.0              54.0            NaN
# 13228                 50.0              11.0              69.0            NaN
# 13229                 41.0               4.0              41.0            NaN
# 13230                 72.0               0.0               NaN           DOME
# 13231                 72.0               0.0               NaN           DOME
#
# [2423 rows x 17 columns]

# %% [markdown]
# ## The function below adds the "final_spread column to the spread dataframe

# %%
def finalspread(home, away):
    return home - away

# %%
spread['final_spread'] = finalspread(spread['score_home'], spread['score_away'])
spread.reset_index(drop = True, inplace = True)

# %%
spread.reset_index(drop=True, inplace=True)
spread['over_under_line'] = spread.over_under_line.astype(float)

# %% [markdown]
# ## Teams
#
# ### I will be keeping team_division as divisiional games actually have a significant dilema on spread.

# %%
teams
# Out:
#                    team_name team_name_short team_id team_id_pfr  \
# 0          Arizona Cardinals       Cardinals     ARI         CRD
# 1          Phoenix Cardinals       Cardinals     ARI         CRD
# 2        St. Louis Cardinals       Cardinals     ARI         ARI
# 3            Atlanta Falcons         Falcons     ATL         ATL
# 4           Baltimore Ravens          Ravens     BAL         RAV
# 5              Buffalo Bills           Bills     BUF         BUF
# 6          Carolina Panthers        Panthers     CAR         CAR
# 7              Chicago Bears           Bears     CHI         CHI
# 8         Cincinnati Bengals         Bengals     CIN         CIN
# 9           Cleveland Browns          Browns     CLE         CLE
# 10            Dallas Cowboys         Cowboys     DAL         DAL
# 11            Denver Broncos         Broncos     DEN         DEN
# 12             Detroit Lions           Lions     DET         DET
# 13         Green Bay Packers         Packers      GB         GNB
# 14            Houston Texans          Texans     HOU         HTX
# 15           Baltimore Colts           Colts     IND         CLT
# 16        Indianapolis Colts           Colts     IND         CLT
# 17      Jacksonville Jaguars         Jaguars     JAX         JAX
# 18        Kansas City Chiefs          Chiefs      KC         KAN
# 19      Los Angeles Chargers        Chargers     LAC         SDG
# 20        San Diego Chargers        Chargers     LAC         SDG
# 21          Los Angeles Rams            Rams     LAR         RAM
# 22            St. Louis Rams            Rams     LAR         RAM
# 23            Miami Dolphins        Dolphins     MIA         MIA
# 24         Minnesota Vikings         Vikings     MIN         MIN
# 25      New England Patriots        Patriots      NE         NWE
# 26           Boston Patriots        Patriots      NE         NWE
# 27        New Orleans Saints          Saints      NO         NOR
# 28           New York Giants          Giants     NYG         NYG
# 29             New York Jets            Jets     NYJ         NYJ
# 30       Los Angeles Raiders         Raiders     LVR         RAI
# 31         Las Vegas Raiders         Raiders     LVR         RAI
# 32           Oakland Raiders         Raiders     LVR         RAI
# 33       Philadelphia Eagles          Eagles     PHI         PHI
# 34       Pittsburgh Steelers        Steelers     PIT         PIT
# 35          Seattle Seahawks        Seahawks     SEA         SEA
# 36       San Francisco 49ers           49ers      SF         SFO
# 37      Tampa Bay Buccaneers      Buccaneers      TB         TAM
# 38            Houston Oilers          Oilers     TEN         OTI
# 39          Tennessee Oilers          Oilers     TEN         OTI
# 40          Tennessee Titans          Titans     TEN         OTI
# 41       Washington Redskins      Washington     WAS         WAS
# 42  Washington Football Team      Washington     WAS         WAS
#
#    team_conference team_division team_conference_pre2002 team_division_pre2002
# 0              NFC      NFC West                     NFC              NFC West
# 1              NFC           NaN                     NFC              NFC East
# 2              NFC           NaN                     NFC              NFC East
# 3              NFC     NFC South                     NFC              NFC West
# 4              AFC     AFC North                     AFC           AFC Central
# 5              AFC      AFC East                     AFC              AFC East
# 6              NFC     NFC South                     NFC              NFC West
# 7              NFC     NFC North                     NFC           NFC Central
# 8              AFC     AFC North                     AFC           AFC Central
# 9              AFC     AFC North                     AFC           AFC Central
# 10             NFC      NFC East                     NFC              NFC East
# 11             AFC      AFC West                     AFC              AFC West
# 12             NFC     NFC North                     NFC           NFC Central
# 13             NFC     NFC North                     NFC           NFC Central
# 14             AFC     AFC South                     AFC                   NaN
# 15             AFC           NaN                     AFC              AFC East
# 16             AFC     AFC South                     AFC              AFC East
# 17             AFC     AFC South                     AFC           AFC Central
# 18             AFC      AFC West                     AFC              AFC West
# 19             AFC      AFC West                     AFC              AFC West
# 20             AFC      AFC West                     AFC              AFC West
# 21             NFC      NFC West                     NFC              NFC West
# 22             NFC           NaN                     NFC              NFC West
# 23             AFC      AFC East                     AFC              AFC East
# 24             NFC     NFC North                     NFC           NFC Central
# 25             AFC      AFC East                     AFC              AFC East
# 26             AFC           NaN                     AFC                   NaN
# 27             NFC     NFC South                     NFC              NFC West
# 28             NFC      NFC East                     NFC              NFC East
# 29             NFC      AFC East                     NFC              AFC East
# 30             AFC           NaN                     AFC              AFC West
# 31             AFC           NaN                     AFC              AFC West
# 32             AFC      AFC West                     AFC              AFC West
# 33             NFC      NFC East                     NFC              NFC East
# 34             AFC     AFC North                     AFC           AFC Central
# 35             NFC      NFC West                     AFC              AFC West
# 36             NFC      NFC West                     NFC              NFC West
# 37             NFC     NFC South                     NFC           NFC Central
# 38             AFC           NaN                     AFC           AFC Central
# 39             AFC           NaN                     AFC           AFC Central
# 40             AFC     AFC South                     AFC           AFC Central
# 41             NFC      NFC East                     NFC              NFC East
# 42             NFC      NFC East                     NFC              NFC East

# %%
teams.drop(columns = ['team_name_short','team_id_pfr','team_conference','team_conference_pre2002','team_division_pre2002'], inplace = True)

# %%
teams
# Out:
#                    team_name team_id team_division
# 0          Arizona Cardinals     ARI      NFC West
# 1          Phoenix Cardinals     ARI           NaN
# 2        St. Louis Cardinals     ARI           NaN
# 3            Atlanta Falcons     ATL     NFC South
# 4           Baltimore Ravens     BAL     AFC North
# 5              Buffalo Bills     BUF      AFC East
# 6          Carolina Panthers     CAR     NFC South
# 7              Chicago Bears     CHI     NFC North
# 8         Cincinnati Bengals     CIN     AFC North
# 9           Cleveland Browns     CLE     AFC North
# 10            Dallas Cowboys     DAL      NFC East
# 11            Denver Broncos     DEN      AFC West
# 12             Detroit Lions     DET     NFC North
# 13         Green Bay Packers      GB     NFC North
# 14            Houston Texans     HOU     AFC South
# 15           Baltimore Colts     IND           NaN
# 16        Indianapolis Colts     IND     AFC South
# 17      Jacksonville Jaguars     JAX     AFC South
# 18        Kansas City Chiefs      KC      AFC West
# 19      Los Angeles Chargers     LAC      AFC West
# 20        San Diego Chargers     LAC      AFC West
# 21          Los Angeles Rams     LAR      NFC West
# 22            St. Louis Rams     LAR           NaN
# 23            Miami Dolphins     MIA      AFC East
# 24         Minnesota Vikings     MIN     NFC North
# 25      New England Patriots      NE      AFC East
# 26           Boston Patriots      NE           NaN
# 27        New Orleans Saints      NO     NFC South
# 28           New York Giants     NYG      NFC East
# 29             New York Jets     NYJ      AFC East
# 30       Los Angeles Raiders     LVR           NaN
# 31         Las Vegas Raiders     LVR           NaN
# 32           Oakland Raiders     LVR      AFC West
# 33       Philadelphia Eagles     PHI      NFC East
# 34       Pittsburgh Steelers     PIT     AFC North
# 35          Seattle Seahawks     SEA      NFC West
# 36       San Francisco 49ers      SF      NFC West
# 37      Tampa Bay Buccaneers      TB     NFC South
# 38            Houston Oilers     TEN           NaN
# 39          Tennessee Oilers     TEN           NaN
# 40          Tennessee Titans     TEN     AFC South
# 41       Washington Redskins     WAS      NFC East
# 42  Washington Football Team     WAS      NFC East

# %%
#I have to drop the teams who haven't been teams within the last 10 years of the NFL 

teams.drop(index=teams[teams['team_name'] == 'Tennessee Oilerss'].index, inplace = True)
teams.drop(index=teams[teams['team_name'] == 'Houston Oilers'].index, inplace = True)
teams.drop(index=teams[teams['team_name'] == 'Los Angeles Raiders'].index, inplace = True)
teams.drop(index=teams[teams['team_name'] == 'Tennessee Oilers'].index, inplace = True)
teams.drop(index=teams[teams['team_name'] == 'Phoenix Cardinals'].index, inplace = True)
teams.drop(index=teams[teams['team_name'] == 'St. Louis Cardinals'].index, inplace = True)
teams.drop(index=teams[teams['team_name'] == 'Boston Patriots'].index, inplace = True)
teams.drop(index=teams[teams['team_name'] == 'Baltimore Colts'].index, inplace = True)
teams.reset_index(drop=True, inplace=True)
teams['team_name'].str.strip()
teams
# Out:
#                    team_name team_id team_division
# 0          Arizona Cardinals     ARI      NFC West
# 1            Atlanta Falcons     ATL     NFC South
# 2           Baltimore Ravens     BAL     AFC North
# 3              Buffalo Bills     BUF      AFC East
# 4          Carolina Panthers     CAR     NFC South
# 5              Chicago Bears     CHI     NFC North
# 6         Cincinnati Bengals     CIN     AFC North
# 7           Cleveland Browns     CLE     AFC North
# 8             Dallas Cowboys     DAL      NFC East
# 9             Denver Broncos     DEN      AFC West
# 10             Detroit Lions     DET     NFC North
# 11         Green Bay Packers      GB     NFC North
# 12            Houston Texans     HOU     AFC South
# 13        Indianapolis Colts     IND     AFC South
# 14      Jacksonville Jaguars     JAX     AFC South
# 15        Kansas City Chiefs      KC      AFC West
# 16      Los Angeles Chargers     LAC      AFC West
# 17        San Diego Chargers     LAC      AFC West
# 18          Los Angeles Rams     LAR      NFC West
# 19            St. Louis Rams     LAR           NaN
# 20            Miami Dolphins     MIA      AFC East
# 21         Minnesota Vikings     MIN     NFC North
# 22      New England Patriots      NE      AFC East
# 23        New Orleans Saints      NO     NFC South
# 24           New York Giants     NYG      NFC East
# 25             New York Jets     NYJ      AFC East
# 26         Las Vegas Raiders     LVR           NaN
# 27           Oakland Raiders     LVR      AFC West
# 28       Philadelphia Eagles     PHI      NFC East
# 29       Pittsburgh Steelers     PIT     AFC North
# 30          Seattle Seahawks     SEA      NFC West
# 31       San Francisco 49ers      SF      NFC West
# 32      Tampa Bay Buccaneers      TB     NFC South
# 33          Tennessee Titans     TEN     AFC South
# 34       Washington Redskins     WAS      NFC East
# 35  Washington Football Team     WAS      NFC East

# %% [markdown]
# ## I want to add individual column of conference to the spread and increase the weight of these games...

# %%
divisions = {
    'NFC_West': ['Arizona Cardinals', 'Seattle Seahawks', 'Los Angeles Rams', 'San Francisco 49ers', 'St. Louis Rams'],
    'NFC_South':['Tampa Bay Buccaneers', 'New Orleans Saints','Carolina Panthers','Atlanta Falcons'],
    'NFC_East': ['Washington Football Team','Washington Redskins','New York Giants','Philadelphia Eagles','Dallas Cowboys'],
    'NFC_North': ['Chicago Bears','Detroit Lions','Green Bay Packers','Minnesota Vikings'],
    'AFC_South': ['Tennessee Titans','Jacksonville Jaguars','Indianapolis Colts','Houston Texans'],
    'AFC_North': ['Pittsburgh Steelers','Cincinnati Bengals','Cleveland Browns','Baltimore Ravens'],
    'AFC_West': ['Las Vegas Raiders','Oakland Raiders','San Diego Chargers','Los Angeles Chargers','Denver Broncos','Kansas City Chiefs'],
    'AFC_East': ['New England Patriots','Miami Dolphins','Buffalo Bills','New York Jets']}

# %%
#The Home Team Division 
division_l = []
def get_division(value):
    for value, row in enumerate(spread['team_home']):
        print(value,row)

# %%
#The Away Team Division
#division_2 = []
#for value, row in enumerate(spread['team_away']):
    #print(value,row)
    #division_2.append((divisions.iloc[value]))
    
#spread['away_division'] = division_2

# %%
spread.head(5)
# Out:
#   schedule_date  schedule_season schedule_week  schedule_playoff  \
# 0      9/5/2013             2013             1             False
# 1      9/8/2013             2013             1             False
# 2      9/8/2013             2013             1             False
# 3      9/8/2013             2013             1             False
# 4      9/8/2013             2013             1             False
#
#            team_home  score_home  score_away             team_away  \
# 0     Denver Broncos        49.0        27.0      Baltimore Ravens
# 1      Buffalo Bills        21.0        23.0  New England Patriots
# 2  Carolina Panthers         7.0        12.0      Seattle Seahawks
# 3      Chicago Bears        24.0        21.0    Cincinnati Bengals
# 4   Cleveland Browns        10.0        23.0        Miami Dolphins
#
#   team_favorite_id  spread_favorite  over_under_line  \
# 0              DEN             -7.5             49.5
# 1               NE            -10.5             51.5
# 2              SEA             -3.5             45.0
# 3              CHI             -3.0             42.0
# 4              CLE             -2.5             40.5
#
#                                stadium  stadium_neutral  weather_temperature  \
# 0  Sports Authority Field at Mile High            False                 83.0
# 1                 Ralph Wilson Stadium            False                 65.0
# 2              Bank of America Stadium            False                 87.0
# 3                        Soldier Field            False                 77.0
# 4                  FirstEnergy Stadium            False                 72.0
#
#    weather_wind_mph  weather_humidity weather_detail  final_spread
# 0               7.0              30.0            NaN          22.0
# 1               6.0              55.0            NaN          -2.0
# 2               7.0              48.0            NaN          -5.0
# 3              13.0              79.0            NaN           3.0
# 4              16.0              80.0            NaN         -13.0

# %%
# We are trying to decide whether or not to choose the favortied team for the spread. 
# Favorite team = True/False 
# What division the team is in and whether they won or lost last game would help decide what to favor. 
#New column "won Last game"/True or false manually entering.. 
#a new dataframe that tells you 1/0 if team won or lost. from the previous season. team name and won or loss.
#home favorite = true/false (teamfavoredd to win is home or not home!)

# %%
# SRS_2021 = pd.read_excel('data/SRS 2021.xlsx')
# SRS_2021_2 = pd.read_excel('data/SRS 2021 2.xlsx')
# SRS_2020 = pd.read_excel('data/SRS 2020.xlsx')
# SRS_2020_2 = pd.read_excel('data/SRS 2020 2.xlsx')
# SRS_2019 = pd.read_excel('data/SRS 2019.xlsx')
# SRS_2019_2 = pd.read_excel('data/SRS 2019 2.xlsx')

# %%
# mapping team_id to the correct teams
spread['team_home'] = spread.team_home.map(teams.set_index('team_name')['team_id'].to_dict())
spread['team_away'] = spread.team_away.map(teams.set_index('team_name')['team_id'].to_dict())

# %%
# creating home favorite and away favorite columns (fill na with 0's)
spread.loc[spread.team_favorite_id == spread.team_home, 'home_favorite'] = 1.0
spread.loc[spread.team_favorite_id == spread.team_away, 'away_favorite'] = 1.0
spread.home_favorite.fillna(0.0, inplace=True)
spread.away_favorite.fillna(0.0, inplace=True)

# %%
# creating over / under column (fill na with 0's)
spread.loc[((spread.score_home + spread.score_away) > spread.over_under_line), 'over'] = 1
spread.over.fillna(0, inplace=True)

# %%
# removing extra columns that aren't necessary for analysis
spread = spread[['schedule_date', 'schedule_season', 'schedule_week', 'team_home',
       'team_away', 'team_favorite_id', 'spread_favorite',
       'over_under_line', 'weather_temperature',
       'weather_wind_mph', 'score_home', 'score_away',
       'stadium_neutral', 'home_favorite', 'away_favorite',
       'over']]

# %%
spread
# Out:
#      schedule_date  schedule_season schedule_week team_home team_away  \
# 0         9/5/2013             2013             1       DEN       BAL
# 1         9/8/2013             2013             1       BUF        NE
# 2         9/8/2013             2013             1       CAR       SEA
# 3         9/8/2013             2013             1       CHI       CIN
# 4         9/8/2013             2013             1       CLE       MIA
# ...            ...              ...           ...       ...       ...
# 2418     1/23/2022             2021      Division        KC       BUF
# 2419     1/23/2022             2021      Division        TB       LAR
# 2420     1/30/2022             2021    Conference        KC       CIN
# 2421     1/30/2022             2021    Conference       LAR        SF
# 2422     2/13/2022             2021     Superbowl       LAR       CIN
#
#      team_favorite_id  spread_favorite  over_under_line  weather_temperature  \
# 0                 DEN             -7.5             49.5                 83.0
# 1                  NE            -10.5             51.5                 65.0
# 2                 SEA             -3.5             45.0                 87.0
# 3                 CHI             -3.0             42.0                 77.0
# 4                 CLE             -2.5             40.5                 72.0
# ...               ...              ...              ...                  ...
# 2418               KC             -2.5             54.0                 35.0
# 2419               TB             -3.0             48.0                 50.0
# 2420               KC             -7.0             54.5                 41.0
# 2421              LAR             -3.5             46.0                 72.0
# 2422              LAR             -4.0             48.5                 72.0
#
#       weather_wind_mph  score_home  score_away  stadium_neutral  \
# 0                  7.0        49.0        27.0            False
# 1                  6.0        21.0        23.0            False
# 2                  7.0         7.0        12.0            False
# 3                 13.0        24.0        21.0            False
# 4                 16.0        10.0        23.0            False
# ...                ...         ...         ...              ...
# 2418               6.0        42.0        36.0            False
# 2419              11.0        27.0        30.0            False
# 2420               4.0        24.0        27.0            False
# 2421               0.0        20.0        17.0            False
# 2422               0.0         NaN         NaN             True
#
#       home_favorite  away_favorite  over
# 0               1.0            0.0   1.0
# 1               0.0            1.0   0.0
# 2               0.0            1.0   0.0
# 3               1.0            0.0   1.0
# 4               1.0            0.0   0.0
# ...             ...            ...   ...
# 2418            1.0            0.0   1.0
# 2419            1.0            0.0   1.0
# 2420            1.0            0.0   0.0
# 2421            1.0            0.0   0.0
# 2422            1.0            0.0   0.0
#
# [2423 rows x 16 columns]

# %%
spread['result'] = (spread.score_home > spread.score_away).astype(int)
# Out:
# <ipython-input-27-725b9941b1d0>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   spread['result'] = (spread.score_home > spread.score_away).astype(int)

# %%
# some percentages to take into consideration when betting
home_win = "{:.2f}".format((sum((spread.result == 1) & (spread.stadium_neutral == 0)) / len(spread)) * 100)
away_win = "{:.2f}".format((sum((spread.result == 0) & (spread.stadium_neutral == 0)) / len(spread)) * 100)
under_line = "{:.2f}".format((sum((spread.score_home + spread.score_away) < spread.over_under_line.astype(float)) / len(spread)) * 100)
over_line = "{:.2f}".format((sum((spread.score_home + spread.score_away) > spread.over_under_line.astype(float)) / len(spread)) * 100)

favored = "{:.2f}".format((sum(((spread.home_favorite == 1) & (spread.result == 1)) | ((spread.away_favorite == 1) & (spread.result == 0)))
                           / len(spread)) * 100)

cover = "{:.2f}".format((sum(((spread.home_favorite == 1) & ((spread.score_away - spread.score_home) < spread.spread_favorite.astype(float))) | 
                             ((spread.away_favorite == 1) & ((spread.score_home - spread.score_away) < spread.spread_favorite.astype(float)))) 
                         / len(spread)) * 100)

ats = "{:.2f}".format((sum(((spread.home_favorite == 1) & ((spread.score_away - spread.score_home) > spread.spread_favorite.astype(float))) | 
                           ((spread.away_favorite == 1) & ((spread.score_home - spread.score_away) > spread.spread_favorite.astype(float)))) 
                       / len(spread)) * 100)

# %%
# print all percentages
print("Number of Games: " + str(len(spread)))
print("Home Straight Up Win Percentage: " + home_win + "%")
print("Away Straight Up Win Percentage: " + away_win + "%")
print("Under Percentage: " + under_line + "%")
print("Over Percentage: " + over_line + "%")
print("Favored Win Percentage: " + favored + "%")
print("Cover The Spread Percentage: " + cover + "%")
print("Against The Spread Percentage: " + ats + "%")
# Out:
# Number of Games: 2423
# Home Straight Up Win Percentage: 54.77%
# Away Straight Up Win Percentage: 43.66%
# Under Percentage: 50.64%
# Over Percentage: 47.79%
# Favored Win Percentage: 65.66%
# Cover The Spread Percentage: 46.47%
# Against The Spread Percentage: 50.06%

# %%
# creating 2 separate dataframes with the home teams / scores and the away teams / scores
score = spread.groupby(['schedule_season', 'schedule_week', 'team_home']).mean()[['score_home', 'score_away']].reset_index()
aw_score = spread.groupby(['schedule_season', 'schedule_week', 'team_away']).mean()[['score_home', 'score_away']].reset_index()

# create total pts column
score['point_diff'] = score.score_home - score.score_away
aw_score['point_diff'] = aw_score.score_away - aw_score.score_home

# append the two dataframes
score = score.append(aw_score, ignore_index=True, sort=True)

# fill null values
score.team_home.fillna(score.team_away, inplace=True)

# sort by season and week 
score.sort_values(['schedule_season', 'schedule_week'], ascending = [True, True], inplace=True)

# removing unneeded columns & changing column name 
score = score[['schedule_season', 'schedule_week', 'team_home', 'point_diff']]
score.rename(columns={'team_home' : 'team'}, inplace=True)

# %%
# dictionary of dataframes - separate dataframe for each team
tm_dict = {}
for key in score.team.unique():
    tm_dict[key] = score[score.team == key].reset_index(drop=True)

# %%
# dataframe to populate
pts_diff = pd.DataFrame()

# for loop to create a rolling average of the previous games for each season
for yr in score.schedule_season.unique():
    for tm in score.team.unique():
        data = tm_dict[tm].copy()
        data = data[data.schedule_season == yr]
        
        data.loc[:, 'avg_pts_diff'] = data.point_diff.shift().expanding().mean()
        
        pts_diff = pts_diff.append(data)

# %%
# merging to df and changing column names
spread = spread.merge(pts_diff[['schedule_season', 'schedule_week', 'team', 'avg_pts_diff']], 
              left_on=['schedule_season', 'schedule_week', 'team_home'], right_on=['schedule_season', 'schedule_week', 'team'],
              how='left')

spread.rename(columns={'avg_pts_diff' : 'hm_avg_pts_diff'}, inplace=True)

spread = spread.merge(pts_diff[['schedule_season', 'schedule_week', 'team', 'avg_pts_diff']], 
              left_on=['schedule_season', 'schedule_week', 'team_away'], right_on=['schedule_season', 'schedule_week', 'team'],
              how='left')

spread.rename(columns={'avg_pts_diff' : 'aw_avg_pts_diff'}, inplace=True)

# %%
pts_diff.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 4846 entries, 0 to 151
# Data columns (total 5 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   schedule_season  4846 non-null   int64
#  1   schedule_week    4846 non-null   object
#  2   team             4846 non-null   object
#  3   point_diff       4844 non-null   float64
#  4   avg_pts_diff     4558 non-null   float64
# dtypes: float64(2), int64(1), object(2)
# memory usage: 227.2+ KB

# %%
# average point differential over entire season
total_season = pts_diff.groupby(['schedule_season', 'team']).mean()['point_diff'].reset_index()

# %%
# adding schedule week for merge and adding one to the season for prediction
total_season['schedule_week'] = 1
total_season['schedule_season'] += 1

# %%
total_season['schedule_week'] = total_season['schedule_week'].astype(str)

# %%
# cleaning of columns
spread = spread[['schedule_date', 'schedule_season', 'schedule_week', 'team_home',
       'team_away', 'team_favorite_id', 'spread_favorite', 'over_under_line',
       'weather_temperature', 'weather_wind_mph', 'score_home', 'score_away', 'stadium_neutral', 'home_favorite',
       'away_favorite', 'hm_avg_pts_diff','aw_avg_pts_diff', 'over', 'result']]

# %%
# merge to have previous seasons average point differential

df = spread.merge(total_season[['schedule_season', 'schedule_week', 'team', 'point_diff']], 
              left_on=['schedule_season', 'schedule_week', 'team_home'], right_on=['schedule_season', 'schedule_week', 'team'],
              how='left')

spread.rename(columns={'point_diff' : 'hm_avg_diff'}, inplace=True)

spread = spread.merge(total_season[['schedule_season', 'schedule_week', 'team', 'point_diff']], 
              left_on=['schedule_season', 'schedule_week', 'team_away'], right_on=['schedule_season', 'schedule_week', 'team'],
              how='left')

df.rename(columns={'point_diff' : 'aw_avg_diff'}, inplace=True)

# %%
spread
# Out:
#      schedule_date  schedule_season schedule_week team_home team_away  \
# 0         9/5/2013             2013             1       DEN       BAL
# 1         9/8/2013             2013             1       BUF        NE
# 2         9/8/2013             2013             1       CAR       SEA
# 3         9/8/2013             2013             1       CHI       CIN
# 4         9/8/2013             2013             1       CLE       MIA
# ...            ...              ...           ...       ...       ...
# 2418     1/23/2022             2021      Division        KC       BUF
# 2419     1/23/2022             2021      Division        TB       LAR
# 2420     1/30/2022             2021    Conference        KC       CIN
# 2421     1/30/2022             2021    Conference       LAR        SF
# 2422     2/13/2022             2021     Superbowl       LAR       CIN
#
#      team_favorite_id  spread_favorite  over_under_line  weather_temperature  \
# 0                 DEN             -7.5             49.5                 83.0
# 1                  NE            -10.5             51.5                 65.0
# 2                 SEA             -3.5             45.0                 87.0
# 3                 CHI             -3.0             42.0                 77.0
# 4                 CLE             -2.5             40.5                 72.0
# ...               ...              ...              ...                  ...
# 2418               KC             -2.5             54.0                 35.0
# 2419               TB             -3.0             48.0                 50.0
# 2420               KC             -7.0             54.5                 41.0
# 2421              LAR             -3.5             46.0                 72.0
# 2422              LAR             -4.0             48.5                 72.0
#
#       weather_wind_mph  ...  score_away  stadium_neutral  home_favorite  \
# 0                  7.0  ...        27.0            False            1.0
# 1                  6.0  ...        23.0            False            0.0
# 2                  7.0  ...        12.0            False            0.0
# 3                 13.0  ...        21.0            False            1.0
# 4                 16.0  ...        23.0            False            1.0
# ...                ...  ...         ...              ...            ...
# 2418               6.0  ...        36.0            False            1.0
# 2419              11.0  ...        30.0            False            1.0
# 2420               4.0  ...        27.0            False            1.0
# 2421               0.0  ...        17.0            False            1.0
# 2422               0.0  ...         NaN             True            1.0
#
#       away_favorite  hm_avg_pts_diff  aw_avg_pts_diff  over  result  team  \
# 0               0.0              NaN              NaN   1.0       1   NaN
# 1               1.0              NaN              NaN   0.0       0   NaN
# 2               1.0              NaN              NaN   0.0       0   NaN
# 3               0.0              NaN              NaN   1.0       1   NaN
# 4               0.0              NaN              NaN   0.0       0   NaN
# ...             ...              ...              ...   ...     ...   ...
# 2418            0.0         6.277778        11.411765   1.0       1   NaN
# 2419            0.0         9.294118         5.055556   1.0       0   NaN
# 2420            0.0         6.823529         4.941176   0.0       0   NaN
# 2421            0.0         5.176471         3.647059   0.0       1   NaN
# 2422            0.0         4.947368         4.736842   0.0       0   NaN
#
#      point_diff
# 0           NaN
# 1           NaN
# 2           NaN
# 3           NaN
# 4           NaN
# ...         ...
# 2418        NaN
# 2419        NaN
# 2420        NaN
# 2421        NaN
# 2422        NaN
#
# [2423 rows x 21 columns]

# %%
spread['aw_avg_pts_diff'].mode()
# Out:
# 0    3.0
# dtype: float64

# %%
# fill null values - filled with the mode
spread.hm_avg_pts_diff.fillna(-1.0, inplace=True)
spread.aw_avg_pts_diff.fillna(3.0,inplace=True)

# %%
spread.isnull().sum()
# Out:
# schedule_date          0
# schedule_season        0
# schedule_week          0
# team_home              0
# team_away              0
# team_favorite_id       0
# spread_favorite        0
# over_under_line        0
# weather_temperature    0
# weather_wind_mph       0
# score_home             0
# score_away             0
# stadium_neutral        0
# home_favorite          0
# away_favorite          0
# hm_avg_pts_diff        0
# aw_avg_pts_diff        0
# over                   0
# result                 0
# dtype: int64

# %%
spread.describe()
# Out:
#        schedule_season  spread_favorite  over_under_line  weather_temperature  \
# count      1880.000000      1880.000000      1880.000000          1880.000000
# mean       2016.240957        -5.275266        45.834309            62.739362
# std           2.336950         3.426783         4.287197            15.834399
# min        2013.000000       -26.500000        36.000000            -6.000000
# 25%        2014.000000        -7.000000        43.000000            53.000000
# 50%        2016.000000        -4.000000        45.500000            71.500000
# 75%        2018.000000        -3.000000        48.500000            72.000000
# max        2021.000000         0.000000        63.500000            97.000000
#
#        weather_wind_mph   score_home   score_away  home_favorite  \
# count       1880.000000  1880.000000  1880.000000    1880.000000
# mean           4.684574    24.251596    21.897340       0.652128
# std            4.854561    10.385338     9.729967       0.476422
# min            0.000000     0.000000     0.000000       0.000000
# 25%            0.000000    17.000000    16.000000       0.000000
# 50%            4.000000    24.000000    21.000000       1.000000
# 75%            8.000000    31.000000    28.000000       1.000000
# max           33.000000    57.000000    56.000000       1.000000
#
#        away_favorite  hm_avg_pts_diff  aw_avg_pts_diff         over  \
# count    1880.000000      1880.000000      1880.000000  1880.000000
# mean        0.343085         0.040331         0.387516     0.483511
# std         0.474866         7.534154         7.650696     0.499861
# min         0.000000       -37.000000       -49.000000     0.000000
# 25%         0.000000        -4.800000        -4.500000     0.000000
# 50%         0.000000        -0.500000         1.105556     0.000000
# 75%         1.000000         5.000000         5.301923     1.000000
# max         1.000000        44.000000        31.500000     1.000000
#
#             result
# count  1880.000000
# mean      0.565426
# std       0.495833
# min       0.000000
# 25%       0.000000
# 50%       1.000000
# 75%       1.000000
# max       1.000000

# %% [markdown]
# ## First Simple Model

# %%
spread
# Out:
#      schedule_date  schedule_season schedule_week team_home team_away  \
# 0         9/5/2013             2013             1       DEN       BAL
# 1         9/8/2013             2013             1       BUF        NE
# 2         9/8/2013             2013             1       CAR       SEA
# 3         9/8/2013             2013             1       CHI       CIN
# 4         9/8/2013             2013             1       CLE       MIA
# ...            ...              ...           ...       ...       ...
# 2418     1/23/2022             2021      Division        KC       BUF
# 2419     1/23/2022             2021      Division        TB       LAR
# 2420     1/30/2022             2021    Conference        KC       CIN
# 2421     1/30/2022             2021    Conference       LAR        SF
# 2422     2/13/2022             2021     Superbowl       LAR       CIN
#
#      team_favorite_id  spread_favorite  over_under_line  weather_temperature  \
# 0                 DEN             -7.5             49.5                 83.0
# 1                  NE            -10.5             51.5                 65.0
# 2                 SEA             -3.5             45.0                 87.0
# 3                 CHI             -3.0             42.0                 77.0
# 4                 CLE             -2.5             40.5                 72.0
# ...               ...              ...              ...                  ...
# 2418               KC             -2.5             54.0                 35.0
# 2419               TB             -3.0             48.0                 50.0
# 2420               KC             -7.0             54.5                 41.0
# 2421              LAR             -3.5             46.0                 72.0
# 2422              LAR             -4.0             48.5                 72.0
#
#       weather_wind_mph  ...  score_away  stadium_neutral  home_favorite  \
# 0                  7.0  ...        27.0            False            1.0
# 1                  6.0  ...        23.0            False            0.0
# 2                  7.0  ...        12.0            False            0.0
# 3                 13.0  ...        21.0            False            1.0
# 4                 16.0  ...        23.0            False            1.0
# ...                ...  ...         ...              ...            ...
# 2418               6.0  ...        36.0            False            1.0
# 2419              11.0  ...        30.0            False            1.0
# 2420               4.0  ...        27.0            False            1.0
# 2421               0.0  ...        17.0            False            1.0
# 2422               0.0  ...         NaN             True            1.0
#
#       away_favorite  hm_avg_pts_diff  aw_avg_pts_diff  over  result  team  \
# 0               0.0        -1.000000         3.000000   1.0       1   NaN
# 1               1.0        -1.000000         3.000000   0.0       0   NaN
# 2               1.0        -1.000000         3.000000   0.0       0   NaN
# 3               0.0        -1.000000         3.000000   1.0       1   NaN
# 4               0.0        -1.000000         3.000000   0.0       0   NaN
# ...             ...              ...              ...   ...     ...   ...
# 2418            0.0         6.277778        11.411765   1.0       1   NaN
# 2419            0.0         9.294118         5.055556   1.0       0   NaN
# 2420            0.0         6.823529         4.941176   0.0       0   NaN
# 2421            0.0         5.176471         3.647059   0.0       1   NaN
# 2422            0.0         4.947368         4.736842   0.0       0   NaN
#
#      point_diff
# 0           NaN
# 1           NaN
# 2           NaN
# 3           NaN
# 4           NaN
# ...         ...
# 2418        NaN
# 2419        NaN
# 2420        NaN
# 2421        NaN
# 2422        NaN
#
# [2423 rows x 21 columns]

# %%
spread.describe()
# Out:
#        schedule_season  spread_favorite  over_under_line  weather_temperature  \
# count      2423.000000      2423.000000      2423.000000          1883.000000
# mean       2017.032191        -5.325010        45.934379            62.737653
# std           2.596088         3.455289         4.292205            15.826410
# min        2013.000000       -26.500000        35.000000            -6.000000
# 25%        2015.000000        -7.000000        43.000000            53.000000
# 50%        2017.000000        -4.000000        45.500000            71.000000
# 75%        2019.000000        -3.000000        48.500000            72.000000
# max        2021.000000         0.000000        63.500000            97.000000
#
#        weather_wind_mph   score_home   score_away  home_favorite  \
# count       1881.000000  2422.000000  2422.000000    2423.000000
# mean           4.682084    23.995458    22.094963       0.638465
# std            4.854472    10.282482     9.852362       0.480544
# min            0.000000     0.000000     0.000000       0.000000
# 25%            0.000000    17.000000    16.000000       0.000000
# 50%            4.000000    24.000000    22.000000       1.000000
# 75%            8.000000    31.000000    28.000000       1.000000
# max           33.000000    57.000000    59.000000       1.000000
#
#        away_favorite  hm_avg_pts_diff  aw_avg_pts_diff         over  \
# count    2423.000000      2423.000000      2423.000000  2423.000000
# mean        0.357821         0.083655         0.517345     0.477920
# std         0.479458         7.907692         7.845892     0.499615
# min         0.000000       -37.000000       -49.000000     0.000000
# 25%         0.000000        -4.861905        -4.408333     0.000000
# 50%         0.000000        -0.416667         1.000000     0.000000
# 75%         1.000000         5.133929         5.408333     1.000000
# max         1.000000        44.000000        49.000000     1.000000
#
#             result  point_diff
# count  2423.000000  127.000000
# mean      0.554684   -0.047696
# std       0.497103    5.279376
# min       0.000000  -13.375000
# 25%       0.000000   -3.562500
# 50%       1.000000   -0.562500
# 75%       1.000000    4.180147
# max       1.000000   11.526316

# %%
spread = spread[['schedule_date', 'schedule_season', 'schedule_week', 'team_home',
       'team_away', 'team_favorite_id', 'spread_favorite', 'over_under_line',
       'weather_temperature', 'weather_wind_mph', 'score_home', 'score_away', 'stadium_neutral', 'home_favorite',
       'away_favorite', 'hm_avg_pts_diff','aw_avg_pts_diff', 'over', 'result']]

# %%
# removing all rows with null values
spread = spread.dropna(how='any',axis=0)

# %%
# initial features possible for model
X = spread[['schedule_season', 'over_under_line', 'spread_favorite',
        'home_favorite', 'hm_avg_pts_diff','aw_avg_pts_diff', 'over']]

y = spread['result']

# %%
# initial features possible for model
X = spread[['over_under_line', 'spread_favorite',
        'home_favorite', 'hm_avg_pts_diff','aw_avg_pts_diff']]

y = spread['over']

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = .3 ,random_state=42)

# %%
cv_scores = cross_val_score(model, X_train, y_train, cv=3)
cv_scores
# Out:
# array([0.51480638, 0.53075171, 0.53881279])

# %%
plt.figure(figsize = (12,10))
corr = X_train.corr()
sns.heatmap(corr, annot=True)
plt.show()

# %%
y_pred = model.predict(X_test_scaled)

model_accuracy = accuracy_score(y_test, y_pred) 
model_recall = recall_score(y_test, y_pred) 
model_precision = precision_score(y_test, y_pred) 
model_f1 = f1_score(y_test, y_pred)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-53-23e7165285db> in <module>
# ----> 1 y_pred = model.predict(X_test_scaled)
#       2
#       3 model_accuracy = accuracy_score(y_test, y_pred)
#       4 model_recall = recall_score(y_test, y_pred)
#       5 model_precision = precision_score(y_test, y_pred)
#
# NameError: name 'X_test_scaled' is not defined

# %%
model_accuracy
model_recall
model_precision
model_f1

# %% [markdown]
# # Adding a little bit more features to prevent over fitting

# %%
#feature Exporation 
#SRS_2021 = pd.read_excel('SRS 2021.xlsx')
#SRS_2021_2 = pd.read_excel('SRS 2021 2.xlsx')
#SRS_2020 = pd.read_excel('SRS 2020.xlsx')
#SRS_2020_2 = pd.read_excel('SRS 2020 2.xlsx')
#SRS_2019 = pd.read_excel('SRS 2019.xlsx')
SRS_2019_2 = pd.read_excel('data/SRS 2019 2.xlsx')

# %%
import statsmodels.api as sm
X = sm.tools.add_constant(X)
logit_model = sm.Logit(y, X)
result = logit_model.fit()

# %%
spread

# %%
SRS_2019_2

# %%
#for row in SRS_2019_2: 
    #for key in dictionary_name:
        #if row['Tm'] in dictionary_name[key]:
            #3SRS_2019_2['SRS'] =

# %% [markdown]
# I wanted to learn more about cross validation, so I googled "" and found [TEXT](source.url)

# %%
models = []

models.append(('LRG', LogisticRegression(solver='liblinear')))
models.append(('KNB', KNeighborsClassifier()))
models.append(('GNB', GaussianNB()))
models.append(('RFC', RandomForestClassifier( n_estimators=100)))
models.append(('DTC', DecisionTreeClassifier( criterion='entropy', max_depth=5)))

# evaluate each model by average and standard deviations of roc auc 
results = []
names = []

for name, m in models:
    kfold = model_selection.KFold(n_splits=5)
    cv_results = model_selection.cross_val_score(m, X, y, cv=kfold, scoring = 'roc_auc')
    results.append(cv_results)
    names.append(name)
    msg = "%s: %f (%f)" % (name, cv_results.mean(), cv_results.std())
    print(msg)
